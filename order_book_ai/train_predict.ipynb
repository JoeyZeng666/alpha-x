# %%
import datetime
import sys
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split

# 读取数据
data  = pd.read_csv('dataset_temp/okxorderbook20240421_1_cleaned_featured_targeted.csv')
# 去除空值
data = data.dropna()
data
# Out:
#                 datetime    server_time  ask_1_price  ask_2_price  \
# 55   2024-04-20 16:00:55  1713628855004      64895.5      64895.6
# 56   2024-04-20 16:00:56  1713628856004      64895.5      64895.6
# 57   2024-04-20 16:00:57  1713628857004      64895.5      64895.6
# 58   2024-04-20 16:00:58  1713628858004      64895.5      64895.6
# 59   2024-04-20 16:00:59  1713628859004      64895.5      64895.6
# ..                   ...            ...          ...          ...
# 137  2024-04-21 04:00:38  1713672038006      65159.3      65159.4
# 138  2024-04-21 04:00:39  1713672039006      65159.3      65159.4
# 139  2024-04-21 04:00:40  1713672040006      65166.5      65166.6
# 140  2024-04-21 04:00:41  1713672041006      65166.5      65166.6
# 141  2024-04-21 04:00:42  1713672042006      65175.8      65175.9
#
#      ask_3_price  bid_3_price  bid_2_price  bid_1_price  ask_1_amount  \
# 55       64895.7      64894.4      64894.7      64895.4      0.360907
# 56       64895.7      64894.4      64894.7      64895.4      0.360907
# 57       64895.7      64894.7      64894.9      64895.4      0.774021
# 58       64895.7      64894.7      64894.9      64895.4      0.391151
# 59       64895.7      64894.7      64894.9      64895.4      0.671261
# ..           ...          ...          ...          ...           ...
# 137      65159.9      65156.0      65157.5      65158.4      1.459707
# 138      65159.9      65158.0      65158.4      65159.2      0.953097
# 139      65166.8      65164.1      65165.9      65166.4      0.368585
# 140      65166.8      65164.1      65165.9      65166.4      0.053493
# 141      65176.0      65173.9      65175.1      65175.7      0.490343
#
#      ask_2_amount  ...  w70_20_10_ask_over_bid  w70_20_10_ask_bid_gap  \
# 55       0.237559  ...                0.426108              -0.402418
# 56       0.237559  ...                0.809774              -0.105110
# 57       0.237559  ...                0.929451              -0.036564
# 58       0.237559  ...                1.011638               0.005785
# 59       0.237559  ...                1.852156               0.298776
# ..            ...  ...                     ...                    ...
# 137      0.228647  ...               18.710398               0.898531
# 138      0.203400  ...                1.437446               0.179469
# 139      0.290000  ...                0.471583              -0.359080
# 140      0.290000  ...                0.149080              -0.740523
# 141      0.190858  ...                1.655924               0.246967
#
#      w80_0_20_ask_over_bid  w80_0_20_ask_bid_gap  w80_10_10_ask_over_bid  \
# 55                0.376789             -0.452655                0.387891
# 56                0.716756             -0.164988                0.737876
# 57                0.874022             -0.067223                0.886641
# 58                0.903216             -0.050853                0.927945
# 59                1.729170              0.267177                1.757763
# ..                     ...                   ...                     ...
# 137              19.812003              0.903902               20.847938
# 138               1.378652              0.159188                1.410336
# 139               0.479413             -0.351888                0.426366
# 140               0.150581             -0.738252                0.113577
# 141               1.592880              0.228657                1.603951
#
#      w80_10_10_ask_bid_gap  w90_0_10_ask_over_bid  w90_0_10_ask_bid_gap  \
# 55               -0.441035               0.358109             -0.472636
# 56               -0.150830               0.681747             -0.189240
# 57               -0.060085               0.853270             -0.079174
# 58               -0.037374               0.862566             -0.073787
# 59                0.274774               1.683976              0.254837
# ..                     ...                    ...                   ...
# 137               0.908458              22.983631              0.916610
# 138               0.170240               1.388695              0.162723
# 139              -0.402165               0.390376             -0.438460
# 140              -0.796014               0.085502             -0.842466
# 141               0.231936               1.561373              0.219169
#
#      is_up  is_down
# 55     1.0      0.0
# 56     1.0      0.0
# 57     1.0      0.0
# 58     1.0      0.0
# 59     1.0      0.0
# ..     ...      ...
# 137    1.0      0.0
# 138    1.0      0.0
# 139    1.0      0.0
# 140    1.0      0.0
# 141    1.0      0.0
#
# [87 rows x 138 columns]

# %%
target = data['is_up']
only_features = data.drop(['is_up','datetime','server_time'], axis=1)

x_train, x_test, y_train, y_test = train_test_split(only_features,target, test_size=0.2, random_state=42)
print("训练集特征：")
print(x_train.shape)
print("\n训练集目标：")
print(y_train.shape)
print("\n测试集特征：")
print(x_test.shape)
print("\n测试集目标：")
print(y_test.shape)
# Out:
# 训练集特征：
# (69, 135)
#
# 训练集目标：
# (69,)
#
# 测试集特征：
# (18, 135)
#
# 测试集目标：
# (18,)

# %%
# 为了自动处理超参数
from sklearn.model_selection import GridSearchCV

from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(max_features='sqrt', random_state=1, n_jobs=-1)

# 这里有更合适的参数么？
#  oob_score 用于
param_grid = {
                "criterion": ['gini','entropy'],
                "min_samples_leaf": [1, 5, 10, 25],
                'min_samples_split': [2, 4, 10, 12, 16, 18, 25, 35],
                "n_estimators": [25, 50,100, 150], 
                'max_depth': [3, 5, 15, 25, 30],
                'max_features': ['sqrt'],
                'oob_score': [True]
            }

gs = GridSearchCV(estimator=rf, param_grid=param_grid, scoring='accuracy', cv=3, n_jobs=-1)
gs = gs.fit(x_train, y_train)
print(gs.best_params_)
print(gs.best_score_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 21
#      10 param_grid = {
#      11                 "criterion": ['gini','entropy'],
#      12                 "min_samples_leaf": [1, 5, 10, 25],
#    (...)
#      17                 'oob_score': [True]
#      18             }
#      20 gs = GridSearchCV(estimator=rf, param_grid=param_grid, scoring='accuracy', cv=3, n_jobs=-1)
# ---> 21 gs = gs.fit(x_train, y_train)
#
# File /opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/model_selection/_search.py:968, in BaseSearchCV.fit(self, X, y, **params)
#     962     results = self._format_results(
#     963         all_candidate_params, n_splits, all_out, all_more_results
#     964     )
#     966     return results
# --> 968 self._run_search(evaluate_candidates)
#     970 # multimetric is determined here because in the case of a callable
#     971 # self.scoring the return type is only known after calling
#     972 first_test_score = all_out[0]["test_scores"]
#
# File /opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1543, in GridSearchCV._run_search(self, evaluate_candidates)
#    1541 def _run_search(self, evaluate_candidates):
#    1542     """Search all candidates in param_grid"""
# -> 1543     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File /opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/model_selection/_search.py:945, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     938 elif len(out) != n_candidates * n_splits:
#     939     raise ValueError(
#     940         "cv.split and cv.get_n_splits returned "
#     941         "inconsistent results. Expected {} "
#     942         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     943     )
# --> 945 _warn_or_raise_about_fit_failures(out, self.error_score)
#     947 # For callable self.scoring, the return type is only know after
#     948 # calling. If the return type is a dictionary, the error scores
#     949 # can now be inserted with the correct key. The type checking
#     950 # of out will be done in `_insert_error_scores`.
#     951 if callable(self.scoring):
#
# File /opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:529, in _warn_or_raise_about_fit_failures(results, error_score)
#     522 if num_failed_fits == num_fits:
#     523     all_fits_failed_message = (
#     524         f"\nAll the {num_fits} fits failed.\n"
#     525         "It is very likely that your model is misconfigured.\n"
#     526         "You can try to debug the error by setting error_score='raise'.\n\n"
#     527         f"Below are more details about the failures:\n{fit_errors_summary}"
#     528     )
# --> 529     raise ValueError(all_fits_failed_message)
#     531 else:
#     532     some_fits_failed_message = (
#     533         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     534         "The score on these train-test partitions for these parameters"
#    (...)
#     538         f"Below are more details about the failures:\n{fit_errors_summary}"
#     539     )
#
# ValueError:
# All the 3840 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1280 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/ensemble/_forest.py", line 363, in fit
#     X, y = self._validate_data(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/base.py", line 650, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/utils/validation.py", line 1273, in check_X_y
#     X = check_array(
#         ^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/utils/validation.py", line 1007, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/utils/_array_api.py", line 746, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/pandas/core/generic.py", line 2153, in __array__
#     arr = np.asarray(values, dtype=dtype)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: could not convert string to float: '2024-04-20 16:01:20'
#
# --------------------------------------------------------------------------------
# 2560 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/ensemble/_forest.py", line 363, in fit
#     X, y = self._validate_data(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/base.py", line 650, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/utils/validation.py", line 1273, in check_X_y
#     X = check_array(
#         ^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/utils/validation.py", line 1007, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/sklearn/utils/_array_api.py", line 746, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ai_trader/lib/python3.11/site-packages/pandas/core/generic.py", line 2153, in __array__
#     arr = np.asarray(values, dtype=dtype)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: could not convert string to float: '2024-04-21 04:00:11'

# %%
# 创建一个新的随机森林对象，放入最佳参数, 重新fit
best_params = gs.best_params_
rf2 = RandomForestClassifier(criterion=best_params['criterion'], 
                             n_estimators=best_params['n_estimators'],
                             min_samples_split=best_params['min_samples_split'],
                             min_samples_leaf=best_params['min_samples_leaf'],
                             max_features=best_params['max_features'],
                             max_depth=best_params['max_depth'],
                             oob_score=best_params['oob_score'],
                             random_state=1,
                             n_jobs=-1)
rf2.fit(x_train, y_train)
df1 = pd.DataFrame(x_train.columns,columns=['Variable'])
df2 = pd.DataFrame(rf2.feature_importances_,columns=['Importance'])
pd.concat([df1,df2],axis=1).sort_values(by='Importance',ascending=False)

# %%
# 正式预测
pred = rf2.predict(x_test)
# 与真实值比较
print(metrics.accuracy_score(y_test,pred))
